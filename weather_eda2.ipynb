# %%
import duckdb
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

conn = duckdb.connect("f1_weather_only.duckdb")

all_weather_query = """
    SELECT 
        *
    FROM weather
    JOIN session USING (session_key)
    ORDER BY date
"""



all_weather_df = conn.execute(all_weather_query).df()


conn.close()

all_weather_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[2], line 18
#      14 """
#      15
#      16
#      17
# ---> 18 all_weather_df = conn.execute(all_weather_query).df()
#      19
#      20
#      21 conn.close()
#
# CatalogException: Catalog Error: Table with name weather does not exist!
# Did you mean "pg_attrdef"?
#
# LINE 4:     FROM weather
#                  ^
