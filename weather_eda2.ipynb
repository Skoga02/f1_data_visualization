# %%
import duckdb
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

conn = duckdb.connect("f1_weather_only.duckdb")

all_weather_query = """
    SELECT 
        *
    FROM weather
    JOIN session USING (session_key)
    ORDER BY date
"""



all_weather_df = conn.execute(all_weather_query).df()


conn.close()

print(len(all_weather_df))
# Out:
# 8021

# %% [markdown]
# ### Simple EDA

# %%
all_weather_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8021 entries, 0 to 8020
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                8021 non-null   datetime64[us, Europe/Stockholm]
#  1   pressure            8021 non-null   float64
#  2   track_temperature   8021 non-null   float64
#  3   rainfall            8021 non-null   float64
#  4   wind_speed          8021 non-null   float64
#  5   wind_direction      8021 non-null   float64
#  6   humidity            8021 non-null   float64
#  7   air_temperature     8021 non-null   float64
#  8   session_key         8021 non-null   int64
#  9   session_type        8021 non-null   str
#  10  session_name        8021 non-null   str
#  11  date_start          8021 non-null   str
#  12  date_end            8021 non-null   str
#  13  meeting_key         8021 non-null   int64
#  14  circuit_key         8021 non-null   int64
#  15  circuit_short_name  8021 non-null   str
#  16  country_key         8021 non-null   int64
#  17  country_code        8021 non-null   str
#  18  country_name        8021 non-null   str
#  19  location            8021 non-null   str
#  20  gmt_offset          8021 non-null   str
#  21  year                8021 non-null   int64
#  22  is_cancelled        8021 non-null   bool
# dtypes: bool(1), datetime64[us, Europe/Stockholm](1), float64(7), int64(5), str(9)
# memory usage: 2.1 MB

# %%
all_weather_df.describe()
# Out:
#           pressure  track_temperature     rainfall   wind_speed  \
# count  8021.000000        8021.000000  8021.000000  8021.000000
# mean    990.656552          34.799414     0.050094     1.851203
# std      48.436003           9.093272     0.204462     1.024957
# min     778.500000           0.000000     0.000000     0.000000
# 25%     992.500000          28.600000     0.000000     1.100000
# 50%    1008.300000          35.800000     0.000000     1.600000
# 75%    1016.100000          41.800000     0.000000     2.400000
# max    1025.600000          59.900000     1.000000     8.500000
#
#        wind_direction     humidity  air_temperature   session_key  \
# count     8021.000000  8021.000000      8021.000000   8021.000000
# mean       175.220509    51.938063        23.531056   9446.489216
# std         82.723158    17.519328         5.113790    537.210209
# min          0.000000     9.200000        10.700000   7763.000000
# 25%        118.200000    39.200000        19.800000   9190.000000
# 50%        177.600000    52.000000        24.000000   9559.000000
# 75%        232.600000    64.000000        27.400000   9858.000000
# max        358.000000    96.000000        35.800000  10033.000000
#
#        meeting_key  circuit_key  country_key         year
# count  8021.000000  8021.000000  8021.000000  8021.000000
# mean   1234.006608    56.332128    43.194739  2024.014337
# std      33.924672    49.326781    49.327621     0.817465
# min    1140.000000     2.000000     1.000000  2023.000000
# 25%    1220.000000    14.000000    13.000000  2023.000000
# 50%    1240.000000    49.000000    19.000000  2024.000000
# 75%    1257.000000    65.000000    46.000000  2025.000000
# max    1277.000000   152.000000   157.000000  2025.000000

# %% [markdown]
# ## Vilket år hade högst average temperatur på alla banor?

# %%
hottest_year = all_weather_df.groupby("year")["air_temperature"].mean().sort_values(ascending=False)

print(hottest_year)
print(f"Genomsnittligt varmaste året: {hottest_year.index[0]}")
# Out:
# year
# 2023    24.683225
# 2024    23.136015
# 2025    22.811066
# Name: air_temperature, dtype: float64
# Genomsnittligt varmaste året: 2023

# %% [markdown]
# ### Top 5 Varmaste asfalt temperaturer

# %%
hottest_tracks = all_weather_df.groupby("circuit_short_name")["track_temperature"].mean().sort_values(ascending=False).head(5)

print(hottest_tracks)
# Out:
# circuit_short_name
# Monza          43.167559
# Miami          42.291216
# Mexico City    42.172575
# Monte Carlo    41.932686
# Austin         41.555290
# Name: track_temperature, dtype: float64

# %% [markdown]
# ### Spara nya väderdatan till csv

# %%
#all_weather_df.to_csv("all_weather_data.csv", index=False)

# %% [markdown]
# ### Extra Matplotlib graf

# %%
grouped_temperature_df = all_weather_df.groupby('circuit_short_name')[['air_temperature', 'track_temperature']].mean().reset_index()


grouped_temperature_df = grouped_temperature_df.sort_values(by='track_temperature', ascending=True)

grouped_temperature_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 grouped_temperature_df = all_weather_df.groupby('circiot_short_name')[['air_temperature', 'track_temperature']].mean().reset_index()
#       2
#       3
#       4 grouped_temperature_df = grouped_temperature_df.sort_values(by='track_temperature', ascending=True)
#
# File c:\Users\filip\OneDrive\Desktop\DE25\Datavisualisering-Grupp\f1_data_visualization\.venv\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File c:\Users\filip\OneDrive\Desktop\DE25\Datavisualisering-Grupp\f1_data_visualization\.venv\Lib\site-packages\pandas\core\frame.py:10821, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10817
#   10818         if level is None and by is None:
#   10819             raise TypeError("You have to supply one of 'by' and 'level'")
#   10820
# > 10821         return DataFrameGroupBy(
#   10822             obj=self,
#   10823             keys=by,
#   10824             level=level,
#
# File c:\Users\filip\OneDrive\Desktop\DE25\Datavisualisering-Grupp\f1_data_visualization\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1095, in GroupBy.__init__(self, obj, keys, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1092 self.dropna = dropna
#    1094 if grouper is None:
# -> 1095     grouper, exclusions, obj = get_grouper(
#    1096         obj,
#    1097         keys,
#    1098         level=level,
#    1099         sort=sort,
#    1100         observed=observed,
#    1101         dropna=self.dropna,
#    1102     )
#    1104 self.observed = observed
#    1105 self.obj = obj
#
# File c:\Users\filip\OneDrive\Desktop\DE25\Datavisualisering-Grupp\f1_data_visualization\.venv\Lib\site-packages\pandas\core\groupby\grouper.py:901, in get_grouper(obj, key, level, sort, observed, validate, dropna)
#     899         in_axis, level, gpr = False, gpr, None
#     900     else:
# --> 901         raise KeyError(gpr)
#     902 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     903     # Add key to exclusions
#     904     exclusions.add(gpr.key)
#
# KeyError: 'circiot_short_name'
